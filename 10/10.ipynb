# %% [markdown]
# ```
#     _/    _/  _/_/_/  _/       Numerical Simulation Laboratory
#    _/_/  _/ _/       _/       Physics Department
#   _/  _/_/    _/    _/       Universita' degli Studi di Milano
#  _/    _/       _/ _/       Prof. D.E. Galli
# _/    _/  _/_/_/  _/_/_/_/ email: Davide.Galli@unimi.it
# ```

# %% [markdown]
# # Lesson 10

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Exercise 10.1

# %% [markdown]
# In this exercise, we solve the TSP using simulated annealing.

# %% [markdown]
# ### Circumference

# %%
cities = np.loadtxt("data/10.1-circ-cities.dat")
out = np.loadtxt("data/10.1-circ-out.dat")
best = np.loadtxt("data/10.1-circ-best.dat", dtype="int")
best = np.append(best, best[0])

# %%
x = np.arange(out.size)
plt.plot(x, out, label="Best");

plt.grid()
plt.title("Path cost ($L_1$)")
plt.xlabel("Generation")
plt.ylabel("Cost")

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.plot(cities[best, 1], cities[best, 2]);
plt.grid()
plt.title("Path")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %% [markdown]
# ### Square

# %%
cities = np.loadtxt("data/10.1-square-cities.dat")
out = np.loadtxt("data/10.1-square-out.dat")
best = np.loadtxt("data/10.1-square-best.dat", dtype="int")
best = np.append(best, best[0])

# %%
x = np.arange(out.size)
plt.plot(x, out, label="Best");

plt.grid()
plt.title("Path cost ($L_1$)")
plt.xlabel("Generation")
plt.ylabel("Cost")

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.plot(cities[best, 1], cities[best, 2]);
plt.grid()
plt.title("Path")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %% [markdown]
# ## Exercise 10.2

# %% [markdown]
# In this exercise, we solve the TSP using 4 MPI threads, that exchange their best path every 15 generations. The plots refer to the data for only one of the threads.

# %% [markdown]
# ### Circumference

# %%
cities = np.loadtxt("data/10.2-circ-cities.dat")
out = np.loadtxt("data/10.2-circ-0-out.dat")
best = np.loadtxt("data/10.2-circ-0-best.dat", dtype="int")
best = np.append(best, best[0])

# %%
x = np.arange(out[:, 0].size)
plt.plot(x, out[:, 0], label="Best");
plt.plot(x, out[:, 1], label="Average of best half");
plt.legend()

plt.grid()
plt.title("Path cost ($L_1$)")
plt.xlabel("Generation")
plt.ylabel("Cost")

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.plot(cities[best, 1], cities[best, 2]);
plt.grid()
plt.title("Path")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %% [markdown]
# ### Square

# %%
cities = np.loadtxt("data/10.2-square-cities.dat")
out = np.loadtxt("data/10.2-square-0-out.dat")
best = np.loadtxt("data/10.2-square-0-best.dat", dtype="int")
best = np.append(best, best[0])

# %%
x = np.arange(out[:, 0].size)
plt.plot(x, out[:, 0], label="Best");
plt.plot(x, out[:, 1], label="Average of best half");
plt.legend()

plt.grid()
plt.title("Path cost ($L_1$)")
plt.xlabel("Generation")
plt.ylabel("Cost")

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.plot(cities[best, 1], cities[best, 2]);
plt.grid()
plt.title("Path")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %% [markdown]
# We observe that we obtained the same path as without using continents. However, this is probably due to the simplicity of the problem at hand; more complex problems are more likely to have benefits from using parallel algorithms.
